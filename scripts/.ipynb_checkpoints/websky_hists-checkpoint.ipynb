# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
halo_coords = "../websky/halos.fits"
hdul = fits.open(halo_coords)
data = hdul[1].data

# %%
m200 = data["M200m"]
z = data["z"]

# %%
plt.hist(m200,bins=100)
plt.xscale("log")

# %%
(1e14 - 0.5e14)/(1e15 - 0.5e14)
# Out:
# 0.05263157894736842

# %%
np.min(m200)
# Out:
# 50000000000000.0

# %%
plt.hist(z)
# Out:
# (array([5.907500e+05, 1.624139e+06, 1.289113e+06, 5.970580e+05,
#         1.967370e+05, 4.970000e+04, 9.969000e+03, 1.625000e+03,
#         2.140000e+02, 2.500000e+01]),
#  array([0.00517946, 0.42081157, 0.83644369, 1.25207581, 1.66770793,
#         2.08334005, 2.49897216, 2.91460428, 3.3302364 , 3.74586852,
#         4.16150064]),
#  <BarContainer object of 10 artists>)

# %%
np.max(z)
# Out:
# 4.161500635733528
